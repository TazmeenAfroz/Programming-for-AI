# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Read the data
df = pd.read_csv('CTI_cat_val_dataset.csv')

df = pd.DataFrame(df)
df
# Out:
#                 category                                  value
# 0                  Other    Aurora_Botnet_Command_Structure.pdf
# 1       Network activity  ip-173-201-21-161.ip.secureserver.net
# 2       Network activity                           ymail.ath.cx
# 3      External analysis                            msinits.exe
# 4      External analysis                              win32.exe
# ...                  ...                                    ...
# 74089   Network activity                                163.com
# 74090   Network activity                               ncph.net
# 74091   Network activity                       enjoy.bmwsee.com
# 74092   Network activity                     tthacker.cublog.cn
# 74093   Network activity                       www.mghacker.com
#
# [74094 rows x 2 columns]

# %%
#for using by default pallete you have to first import mcolors 
import matplotlib.colors as mcolors
#stor the colors values in the list
colors = list(mcolors.TABLEAU_COLORS.values())

#plot the bar graph for different values
df['category'].value_counts().plot(kind='bar', color=colors, width=0.8, figsize=(10, 5))
plt.title('Category Distribution')
plt.xlabel('Category')
plt.ylabel('Number of Occurrences')
plt.show()
